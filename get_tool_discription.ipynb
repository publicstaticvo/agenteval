# %%
import json

def load_local(fn):
    d = []
    with open(fn, "r+", encoding="utf-8") as f:
        for line in f: 
            if line.strip():
                try:
                    d.append(json.loads(line.strip()))
                except:
                    pass
    return d

def load_local_binary(fn, encoding='utf-8'):
    d = []
    with open(fn, "rb") as f:
        binary_text = f.read()
        binary_lines = binary_text.split(b"\n")
        for line in binary_lines:
            try:
                line = line.decode(encoding)
                if line.strip():
                    d.append(json.loads(line.strip()))
            except:
                pass
    return d

def print_json(d, fn):
    with open(fn, "w+", encoding="utf-8") as f:
        for x in d:
            f.write(json.dumps(x, ensure_ascii=False) + "\n")

def yield_local(fn):
    with open(fn, "r+", encoding="utf-8") as f:
        for line in f:
            if line.strip():
                try:
                    yield json.loads(line)
                except:
                    pass

def yield_local_binary(fn, encoding='utf-8'):
    with open(fn, "rb") as f:
        binary_text = f.read()
        binary_lines = binary_text.split(b"\n")
        for line in binary_lines:
            try:
                line = line.decode(encoding)
                if line.strip():
                    yield json.loads(line.strip())
            except:
                pass

# %%
import ast
import json
from typing import List, Dict, Any


class ChemistryToolParser:
    """Parser for extracting tool information from Python class definitions."""
    
    def parse_file(self, filepath: str) -> List[Dict[str, str]]:
        """Parse a Python file and extract all tool definitions.
        
        Parameters
        ----------
        filepath : str
            Path to the Python file containing tool class definitions
            
        Returns
        -------
        List[Dict[str, str]]
            List of dictionaries containing tool information
        """
        with open(filepath, 'r') as f:
            content = f.read()
        
        return self.parse_content(content)
    
    def parse_content(self, content: str) -> List[Dict[str, str]]:
        """Parse Python code content and extract tool definitions.
        
        Parameters
        ----------
        content : str
            Python code content as string
            
        Returns
        -------
        List[Dict[str, str]]
            List of dictionaries containing tool information
        """
        tree = ast.parse(content)
        tools = []
        
        for node in ast.walk(tree):
            if isinstance(node, ast.ClassDef):
                tool_info = self._extract_tool_info(node)
                if tool_info:
                    tools.append(tool_info)
        
        return tools
    
    def _extract_tool_info(self, class_node: ast.ClassDef) -> Dict[str, str]:
        """Extract tool information from a class definition node.
        
        Parameters
        ----------
        class_node : ast.ClassDef
            AST node representing a class definition
            
        Returns
        -------
        Dict[str, str]
            Dictionary with name, description, inputs, and outputs
        """
        tool_info = {
            "name": "",
            "description": "",
            "inputs": "",
            "outputs": ""
        }
        
        # Extract class attributes (name and description)
        for item in class_node.body:
            if isinstance(item, ast.AnnAssign) and isinstance(item.target, ast.Name):
                attr_name = item.target.id
                
                if attr_name == "name" and isinstance(item.value, ast.Constant):
                    tool_info["name"] = item.value.value
                elif attr_name == "description" and isinstance(item.value, ast.Constant):
                    tool_info["description"] = item.value.value
        
        # Find the _run method and extract inputs/outputs from docstring
        for item in class_node.body:
            if isinstance(item, ast.FunctionDef) and item.name == "_run":
                inputs, outputs = self._parse_docstring(ast.get_docstring(item), item)
                tool_info["inputs"] = inputs
                tool_info["outputs"] = outputs
                break
        
        # Only return if we found a valid tool (has name and description)
        if tool_info["name"] and tool_info["description"]:
            return tool_info
        
        return None
    
    def _parse_docstring(self, docstring: str, func_node: ast.FunctionDef) -> tuple:
        """Parse function docstring to extract parameters and return types.
        
        Parameters
        ----------
        docstring : str
            The docstring of the function
        func_node : ast.FunctionDef
            AST node of the function
            
        Returns
        -------
        tuple
            (inputs_str, outputs_str)
        """
        if not docstring:
            # Fall back to function signature if no docstring
            return self._extract_from_signature(func_node)
        
        lines = docstring.split('\n')
        inputs = []
        outputs = []
        
        current_section = None
        
        for line in lines:
            line = line.strip()
            
            # Detect sections
            if line.startswith('Parameters'):
                current_section = 'parameters'
                continue
            elif line.startswith('Returns'):
                current_section = 'returns'
                continue
            elif line.startswith('---'):
                continue
            
            # Parse content based on current section
            if current_section == 'parameters' and line and not line.startswith('-'):
                # Format: "param_name: type" or "param_name : type"
                if ':' in line:
                    inputs.append(line)
            elif current_section == 'returns' and line and not line.startswith('-'):
                outputs.append(line)
        
        inputs_str = ', '.join(inputs) if inputs else ""
        outputs_str = ' '.join(outputs) if outputs else ""
        
        return inputs_str, outputs_str
    
    def _extract_from_signature(self, func_node: ast.FunctionDef) -> tuple:
        """Extract input/output info from function signature as fallback.
        
        Parameters
        ----------
        func_node : ast.FunctionDef
            AST node of the function
            
        Returns
        -------
        tuple
            (inputs_str, outputs_str)
        """
        inputs = []
        
        # Extract parameters (skip 'self')
        for arg in func_node.args.args:
            if arg.arg != 'self':
                if arg.annotation:
                    inputs.append(f"{arg.arg}: {ast.unparse(arg.annotation)}")
                else:
                    inputs.append(arg.arg)
        
        # Extract return type
        outputs = ""
        if func_node.returns:
            outputs = ast.unparse(func_node.returns)
        
        return ', '.join(inputs), outputs


example_code = '''
class CalculateSA(BaseTool):
    """Calculate the SA of the compound."""

    name: str = "CalculateSA"
    description: str = "Used to compute the synthetic accessibility (SA) of the given molecule."

    def _run(self, compound: str) -> float:
        """Compute Synthetic Accessibility (SA) of the given SMILES string. Ertl & Schuffenhauer 2009.

        Parameters
        ----------
        compound: Compound in SMILES format

        Returns
        -------
        float: The SA between 1 (easy) and 10 (hard)
        """
        return sascorer.calculateScore(MolFromSmiles(compound))

    async def _arun(self, compound: str) -> float:
        """Use the convert_to_SMILES tool asynchronously."""
        raise NotImplementedError()
'''    
parser = ChemistryToolParser()
tools = parser.parse_content(example_code)

print("Extracted Tools:")
print(json.dumps(tools, indent=2))
# Out:
# Extracted Tools:
# [
#   {
#     "name": "CalculateSA",
#     "description": "Used to compute the synthetic accessibility (SA) of the given molecule.",
#     "inputs": "compound: Compound in SMILES format",
#     "outputs": "float: The SA between 1 (easy) and 10 (hard)"
#   }
# ]

# %%
import inspect
from typing import get_type_hints

def query_name_to_cas(molecule_name: str) -> str:
    """
    Query a molecule name and return its CAS number in Markdown format.
    """
    try:
        mode = "name"
        if is_smiles(molecule_name):
            mode = "smiles"
        url_cid = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/{mode}/{molecule_name}/cids/JSON"
        cid_response = requests.get(url_cid)
        cid_response.raise_for_status()
        cid = cid_response.json()["IdentifierList"]["CID"][0]

        url_data = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/{cid}/JSON"
        data_response = requests.get(url_data)
        data_response.raise_for_status()
        data = data_response.json()

        cas_number = None
        for section in data["Record"]["Section"]:
            if section.get("TOCHeading") == "Names and Identifiers":
                for subsection in section["Section"]:
                    if subsection.get("TOCHeading") == "Other Identifiers":
                        for subsubsection in subsection["Section"]:
                            if subsubsection.get("TOCHeading") == "CAS":
                                cas_number = subsubsection["Information"][0]["Value"]["StringWithMarkup"][0]["String"]
                                break

        if cas_number:
            markdown_result = f"""
### Molecule: {molecule_name}

#### CAS Number

- **CAS**: `{cas_number}`

#### More Information

- [PubChem Compound](https://pubchem.ncbi.nlm.nih.gov/compound/{cid})
"""
            return markdown_result
        else:
            return "CAS number not found."

    except (requests.exceptions.RequestException, KeyError):
        return "Invalid molecule input, no Pubchem entry."
    
sig = inspect.signature(query_name_to_cas)
try:
    type_hints = get_type_hints(query_name_to_cas)
except:
    type_hints = {}

print(f"Function: {query_name_to_cas.__name__}")
print("Parameters:")
for param_name, param in sig.parameters.items():
    if param.annotation != inspect.Parameter.empty:
        # Get the name of the type
        type_name = getattr(param.annotation, '__name__', str(param.annotation))
    else:
        type_name = 'No type hint'
    print(f"  - {param_name}: {type_name}")
    if param.default != inspect.Parameter.empty:
        print(f"    Default: {param.default}")

# Get return type name
if sig.return_annotation != inspect.Signature.empty:
    return_type_name = getattr(sig.return_annotation, '__name__', str(sig.return_annotation))
else:
    return_type_name = 'No type hint'
print(f"Return type: {return_type_name}")
print()
# Out:
# Function: query_name_to_cas
# Parameters:
#   - molecule_name: str
# Return type: str

# %%
import json
import time
import openai
import requests
import subprocess
from inference import call
from typing import List, Optional, Union, Dict
from dataclasses import dataclass, field
with open("../api_key.json") as f: key = json.load(f)['cstcloud']

def get_message(line):
    messages = []
    if 'user_prompt' in line:
        messages.append({"role": 'user', "content": line['user_prompt']})
    elif 'prompt' in line:
        messages.append({"role": 'user', "content": line['prompt']})
    if 'system_prompt' in line:
        messages = [{"role": 'system', "content": line['system_prompt']}] + messages
    return messages

@dataclass
class Args:
    api_key: str = key['key']
    model: str = "deepseek-r1:671b-0528"
    max_tokens: int = 16384
    base_url: str = key['domain']
    stream: bool = False


def call(line, args, output_file="", retry=5):
    # 需要：每个输入样本line的格式为{"system_prompt": ..., "user_prompt": ...}
    # 确保：将一条{"system_prompt": ..., "user_prompt": ..., "greedy": "输出结果"}的数据以"a+"的方式写入输出文件。
    while retry > 0:
        try:
            # 为了节省输入文件大小，可以将组装system_prompt和user_prompt的步骤放在此处。
            messages = get_message(line)
            print(messages)
            response = client.chat.completions.create(model=args.model, messages=messages, max_tokens=args.max_tokens, stream=args.stream)
            if args.stream:
                text = ""
                for chunk in response:
                    if "content" in chunk.choices[0].delta:
                        print(chunk.choices[0].delta.content, end="", flush=True)
                        text += chunk.choices[0].delta.content
            else:
                text = response.choices[0].message.content
            if "</think>" in text:
                think = text[:text.index("</think>")]
                text = text[text.index("</think>") + 8:]
            else:
                think = ""
            if output_file:
                line["greedy"] = text
                with open(output_file, 'a+', encoding="utf-8") as fp:
                    fp.write(json.dumps(line, ensure_ascii=False) + '\n')
            return text, think
        except Exception as e:
            retry -= 1
            print(f"Error: {e}, Retry: {retry}")
            time.sleep(10)


def callr(line, args, output_file="", retry=5):
    # 需要：每个输入样本line的格式为{"system_prompt": ..., "user_prompt": ...}
    # 确保：将一条{"system_prompt": ..., "user_prompt": ..., "greedy": "输出结果"}的数据以"a+"的方式写入输出文件。
    while retry > 0:
        try:
            # 为了节省输入文件大小，可以将组装system_prompt和user_prompt的步骤放在此处。
            messages = get_message(line)
            sampling_params = {
                "model": args.model,
                "messages": messages,
                "temperature": 0.6,
                "top_p": 0.95, "top_k": 20,
                "max_tokens": args.max_tokens,
                "stream": args.stream
            }
            headers = {'Content-Type': 'application/json', 'Authorization': f'Bearer {args.api_key}'}
            url = f"{args.base_url}/v1/chat/completions"
            response = requests.post(url, headers=headers, data=json.dumps(sampling_params))
            response.raise_for_status()
            returns = []
            for choice in json.loads(response.text)['choices']:
                message = choice['message']
                text = message['content']
                if 'reasoning_content' in message:
                    think = message['reasoning_content']
                elif "</think>" in text:
                    think = text[:text.index("</think>")]
                    text = text[text.index("</think>")+8:]
                else:
                    think = ""
                returns.append((text, think))
            return returns
        except Exception as e:
            retry -= 1
            print(f"Error: {e}, Retry: {retry}")
            time.sleep(10)
    
h = {"system_prompt": """你是一个专业的科学智能体研究人员，目前正在与我们中国科学院自动化所合作。由于研究需要，现要求你改造生成一批高质量、专家级的科学研究问题。为确保生成任务的科学性与挑战性，定义“高质量、专家级问题”的标准如下：

目标：构造高质量、专家级、模拟真实科研任务的问题；
要求：
1）要求有一定的复杂性和难度，专业的科研人员难度级别；
2）需至少2个及以上的专业工具；
3）尽量具有真实性；
示例：
原始问题: "What are the technical limitations of ECHs and conductive polymers for biomedical applications?" （ECH 和导电聚合物在生物医学应用方面的技术限制是什么？）
评价: 这是一个典型的低质量、事实检索型query。它的答案需要模型进行简单的搜索。
新问题:
我们来构思一个用于心脏修复的导电水凝胶新体系。显然，老旧的氧化石墨烯或聚苯胺路线问题太多。从近两年的新材料来看，比如MXenes或者导电MOFs，你认为哪个与GelMA这类基质结合，最有潜力同时实现心肌级别的力学性能（大概是多少kPa来着？）和电导率？关键是，怎么设计这个体系才能解耦或者说协同调控这两种性质。
涉及：文献检索工具、数据库工具，最后需要模型推理。
     
""", "user_prompt": """以下是需要你来改造的原始问题：

1. Determine the EState VSA (Valuation Surface Area) indices for the molecule identified by the SLN string N[1]CH=CHCH2CH=@1 by first converting it to its corresponding SMILES representation. （首先将由 SLN 字符串 N[1]CH=CHCH2CH=@1 标识的分子转换为其对应的 SMILES 表示形式，然后确定该分子的 EState VSA（估值表面积）指数。）
2. What is the formal charge of the molecule represented by the SLN string CH3C(=O)OH, when converted to its corresponding SMILES string? （将 SLN 字符串 CH3C(=O)OH 转换为其对应的 SMILES 字符串后，该分子的正式电荷是多少？）
3. Calculate the Chi^1 (Chi-one) cluster index, which represents a topological descriptor related to molecular branching, for the molecule identified by the InChIKey DUYJMQONPNNFPI-UHFFFAOYSA-N by first resolving the InChIKey against the ChemSpider database to obtain the SMILES notation. （首先通过将 InChIKey（DUYJMQONPNNFPI-UHFFFAOYSA-N）在 ChemSpider 数据库中解析以获取 SMILES 表示法，然后计算表示分子支化拓扑描述符的 χ^1（奇一）聚类指数。）
4. Predict the product of a mixture of Ethylidenecyclohexane and HBr.  Then predict the same reaction, adding methyl peroxide into the mixture.  Compare the two products and explain the reaction mechanism. （预测乙叉环己烷与溴化氢混合物的反应产物。然后预测在该混合物中加入过氧化甲基后的相同反应。比较这两种产物并解释反应机制。）
5. I need to synthesize a sample of aspirin.  Please tell me how to synthesize it.  Then tell me the ghs rating of all of the reactants needed. （我需要合成一份阿司匹林的样本。请告诉我如何合成它。然后告诉我所有所需反应物的全球统一制度（GHS）评级。）
6. Could you please find out the PubChem Compound Identifier for Dinitromesitylene?  Once that's done, retrieve the molecular weight of this compound using the CID, and finally, determine its charge based on that same identifier. （能否请您查出二硝基均三甲苯的 PubChem 化合物标识符？完成这一步后，利用该标识符获取该化合物的分子量，最后根据该标识符确定其电荷。）
7. What is the limiting reagent for the reaction 3 Na2S + 2 AlCl3 --> 6 NaCl + 2 Al2S3 when using 91.351 grams of Na2S and 90.8629 grams of AlCl3? （在使用 91.351 克硫化钠（Na₂S）和 90.8629 克氯化铝（AlCl₃）进行反应 3 Na₂S + 2 AlCl₃ → 6 NaCl + 2 Al₂S₃ 时，限制反应物是什么？）
8. How many hydrogen bond donors (HBD) are there in the molecule with the molecule name salicylic acid? （分子名为水杨酸的分子中有多少个氢键供体（HBD）？）

请将以上问题分别从2-3个不同的角度改造成新问题。"""}

# model="qwen3:235b"
args = Args(model="qwen3:235b")
client = openai.OpenAI(base_url=f"{args.base_url}/v1", api_key=args.api_key)
returns = callr(h, args, retry=1)
if returns:
    for text, think in returns:
        print(f"{'*' * 80}\n{think}\n{'+' * 80}\n\n{text}")

# %%
import os
queries = []
i = 0
models = ['qwen3:235b', 'gpt-oss-120b', 'deepseek-reasoner']
# chemcrow
chemcrow = load_local("queries/chemcrow.jsonl")
for x in chemcrow:
    i += 1
    query = x['query']
    tools = [f"chemcrow/{s[7:].strip()}" for s in x['traj'].split("\n") if s.startswith("Action:")]
    queries.append({'q': query, 'tools': tools, "subset": "chemcrow", "id": i, 'request_models': models})
# chemtoolbench
for f in os.listdir("queries/chemtoolbench/chemistry"):
    data = load_local(f"queries/chemtoolbench/chemistry/{f}")
    for x in data:
        i += 1
        query = x['query']
        tools = [y['tool'] for y in x['calling_chain']]
        queries.append({'q': query, 'tools': tools, "subset": "chemtoolbench", "id": i, 'request_models': models})
# scitooleval
for f in os.listdir("queries/scitooleval"):
    data = load_local(f"queries/scitooleval/{f}")
    for x in data:
        i += 1
        query = x['question']
        tools = [f"scitooleval/{t}" for t in x['tool_path']]
        queries.append({'q': query, 'tools': tools, "subset": "scitooleval", "id": i, 'request_models': models})
print_json(queries, "generated/single_query.txt")

# %%
import re
json_pattern = re.compile(r"```(?:json)?(.+)```", re.DOTALL)
json_pattern_fallback = re.compile(r"\{.+\}", re.DOTALL)

def get_transformed_query(pattern: re.Pattern, x: str, i: int, m: str):
    data = json.loads(pattern.findall(x)[-1].strip())['transformed_questions']
    queries = [{'q': d['question'], 'angle': d['perspective'], 'id': i, "model": m} for d in data]
    return queries

data = []
count = [0, 0]
for x in yield_local_binary("generated/single_output.jsonl"):
    count[0] += 1
    for m in x['samples']:
        text = x['samples'][m]
        try:
            data.extend(get_transformed_query(json_pattern, text, x['id'], m))
        except:
            try:
                data.extend(get_transformed_query(json_pattern_fallback, text, x['id'], m))
            except:
                count[1] += 1
                continue
print(count, len(data))
print_json(data, "generated/single_score.jsonl")

# %%
# Out:
# True
# True
# True

# %%
with open("queries/scitooleval/level2_correct_answer.jsonl", "r+", encoding="utf-8") as f:
    for line in f:
        if line.strip():
            try:
                json.loads(line.strip())
            except json.JSONDecodeError:
                print(line)
# Out:
# {"tool_path": ["InChIKeyToSMILES", "GetFractionCSP3", "GetFractionCSP3"], "question": "Determine the molecular similarity and calculate the fraction of sp3-hybridized carbon atoms for the molecules represented by the InChIKey 'GELRVIPPMNMYGS-RVXRQPKJSA-N' the SMILES 'C1CCC(CC1)(C2=CC=CS2)N3CCCCC3'.", }
